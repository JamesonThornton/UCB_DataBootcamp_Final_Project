# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from os import walk
import fastf1

# %%
import fastf1.plotting

# %%
folder = 'F1_Data'
fastf1.Cache.enable_cache('cache')

# %%
f = []
for (dirpath, dirnames, filenames) in walk(os.getcwd()):
    f.extend(filenames)
    break

# %%
f
# Out:
# ['circuits.csv',
#  'constructors.csv',
#  'constructor_results.csv',
#  'constructor_standings.csv',
#  'drivers.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'sprint_results.csv',
#  'status.csv']

# %%
df_circuits = pd.read_csv('circuits.csv')
df_const = pd.read_csv('constructors.csv')
df_const_rslt = pd.read_csv('constructor_results.csv')
df_const_stnd = pd.read_csv('constructor_standings.csv')
df_drivers = pd.read_csv('drivers.csv')
df_driver_stnd = pd.read_csv('driver_standings.csv')
df_lap_times = pd.read_csv('lap_times.csv')
df_pit_stops = pd.read_csv('pit_stops.csv')
df_quali = pd.read_csv('qualifying.csv')
df_races = pd.read_csv('races.csv')
df_results = pd.read_csv('results.csv')
df_seasons = pd.read_csv('seasons.csv')
df_sprint_rslt = pd.read_csv('sprint_results.csv')
df_status = pd.read_csv('status.csv')

# %%
cols_df = pd.DataFrame(
[df_circuits.columns.values,
df_const.columns.values,
df_const_rslt.columns.values,
df_const_stnd.columns.values,
df_drivers.columns.values,
df_driver_stnd.columns.values,
df_lap_times.columns.values,
df_pit_stops.columns.values,
df_quali.columns.values,
df_races.columns.values,
df_results.columns.values,
df_seasons.columns.values,
df_sprint_rslt.columns.values,
df_status.columns.values], 
index=['circuits', 'const', 'const_rslts', 'const_stnd', 'drivers', 
       'driver_stnd', 'lap_times', 'pit_stops', 'quali', 'races', 
      'results', 'seasons', 'sprint_rslt', 'status'])

# %%
cols_df.to_csv('df_columns.csv')

# %%
cols_df.transpose()
# Out:
#       circuits           const           const_rslts              const_stnd  \
# 0    circuitId   constructorId  constructorResultsId  constructorStandingsId
# 1   circuitRef  constructorRef                raceId                  raceId
# 2         name            name         constructorId           constructorId
# 3     location     nationality                points                  points
# 4      country             url                status                position
# 5          lat            None                  None            positionText
# 6          lng            None                  None                    wins
# 7          alt            None                  None                    None
# 8          url            None                  None                    None
# 9         None            None                  None                    None
# 10        None            None                  None                    None
# ...

# %%
print('df_circuits   :',   df_circuits.shape   )
print('df_const      :',      df_const.shape      )
print('df_const_rslt :', df_const_rslt.shape )
print('df_const_stnd :', df_const_stnd.shape )
print('df_drivers    :',    df_drivers.shape    )
print('df_driver_stnd:', df_driver_stnd.shape)
print('df_lap_times  :',  df_lap_times.shape  )
print('df_pit_stops  :',  df_pit_stops.shape  )
print('df_quali      :',      df_quali.shape      )
print('df_races      :',      df_races.shape      )
print('df_results    :',    df_results.shape    )
print('df_seasons    :',    df_seasons.shape    )
print('df_sprint_rslt:',    df_sprint_rslt.shape    )
print('df_status     :',     df_status.shape     )
# Out:
# df_circuits   : (76, 9)
# df_const      : (211, 5)
# df_const_rslt : (12170, 5)
# df_const_stnd : (12931, 7)
# df_drivers    : (855, 9)
# df_driver_stnd: (33882, 7)
# df_lap_times  : (538121, 6)
# df_pit_stops  : (9634, 7)
# df_quali      : (9575, 9)
# df_races      : (1079, 18)
# df_results    : (25840, 18)
# df_seasons    : (73, 2)
# df_sprint_rslt: (120, 16)
# df_status     : (139, 2)

# %%
df_list = [df_circuits,
df_const,
df_const_rslt,
df_const_stnd,
df_drivers,
df_driver_stnd,
df_lap_times,
df_pit_stops,
df_quali,
df_races,
df_results,
df_seasons,
df_sprint_rslt,           
df_status]

# %% [markdown]
# # Count of Unique values per column

# %%
for count, df in enumerate(df_list):
    temp = list()
    for col in df.columns:
        temp.extend([col, df[col].unique().shape])
    print(count, temp)
# Out:
# 0 ['circuitId', (76,), 'circuitRef', (76,), 'name', (76,), 'location', (74,), 'country', (34,), 'lat', (76,), 'lng', (76,), 'alt', (66,), 'url', (76,)]
# 1 ['constructorId', (211,), 'constructorRef', (211,), 'name', (211,), 'nationality', (24,), 'url', (174,)]
# 2 ['constructorResultsId', (12170,), 'raceId', (1016,), 'constructorId', (175,), 'points', (54,), 'status', (2,)]
# 3 ['constructorStandingsId', (12931,), 'raceId', (1015,), 'constructorId', (159,), 'points', (539,), 'position', (22,), 'positionText', (23,), 'wins', (20,)]
# 4 ['driverId', (855,), 'driverRef', (855,), 'number', (44,), 'code', (93,), 'forename', (475,), 'surname', (796,), 'dob', (837,), 'nationality', (42,), 'url', (855,)]
# 5 ['driverStandingsId', (33882,), 'raceId', (1079,), 'driverId', (848,), 'points', (418,), 'position', (108,), 'positionText', (109,), 'wins', (16,)]
# 6 ['raceId', (498,), 'driverId', (137,), 'lap', (87,), 'position', (24,), 'time', (74431,), 'milliseconds', (74431,)]
# ...

# %%
df_const_stnd.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
df_driver_stnd.wins.sort_values(ascending=False)
# Out:
# 33878    15
# 33856    14
# 33820    14
# 33796    13
# 1917     13
#          ..
# 12153     0
# 12152     0
# 12151     0
# 12149     0
# 33881     0
# Name: wins, Length: 33882, dtype: int64

# %%
session = fastf1.get_session(2019, 'Monza', 'Q')

# %%
session.load(telemetry=True, laps=True, weather=True)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Qualifying [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
session.event
# Out:
# RoundNumber                                                    14
# Country                                                     Italy
# Location                                                    Monza
# OfficialEventName    FORMULA 1 GRAN PREMIO HEINEKEN D’ITALIA 2019
# EventDate                                     2019-09-08 00:00:00
# EventName                                      Italian Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                                  2019-09-06 00:00:00
# Session2                                               Practice 2
# Session2Date                                  2019-09-06 00:00:00
# Session3                                               Practice 3
# Session3Date                                  2019-09-07 00:00:00
# Session4                                               Qualifying
# ...

# %%
session = fastf1.get_event(2021, 7)

# %%
session = fastf1.get_event(2021,22)

# %%
session
# Out:
# RoundNumber                                                         22
# Country                                                            UAE
# Location                                                     Abu Dhabi
# OfficialEventName    FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...
# EventDate                                          2021-12-12 00:00:00
# EventName                                         Abu Dhabi Grand Prix
# EventFormat                                               conventional
# Session1                                                    Practice 1
# Session1Date                                       2021-12-10 00:00:00
# Session2                                                    Practice 2
# Session2Date                                       2021-12-10 00:00:00
# Session3                                                    Practice 3
# Session3Date                                       2021-12-11 00:00:00
# ...

# %%
race = session.get_race()

# %%
race.load(telemetry=True, laps=True, weather=True)
# Out:
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
schedule = fastf1.get_event_schedule(2022)

# %%
schedule
# Out:
#     RoundNumber        Country           Location  \
# 0             0          Spain              Spain
# 1             0        Bahrain            Bahrain
# 2             1        Bahrain             Sakhir
# 3             2   Saudi Arabia             Jeddah
# 4             3      Australia          Melbourne
# 5             4          Italy              Imola
# 6             5  United States              Miami
# 7             6          Spain          Barcelona
# 8             7         Monaco             Monaco
# 9             8     Azerbaijan               Baku
# 10            9         Canada           Montréal
# 11           10  Great Britain        Silverstone
# 12           11        Austria          Spielberg
# 13           12         France       Le Castellet
# 14           13        Hungary           Budapest
# 15           14        Belgium  Spa-Francorchamps
# 16           15    Netherlands          Zandvoort
# 17           16          Italy              Monza
# ...
